# %%
import pandas as pd
import json

# %%
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json"
first_json = pd.read_json(url)
first_json.head()
# Out:
#    integer            datetime  category
# 0        5 2015-01-01 00:00:00         0
# 1        5 2015-01-01 00:00:01         0
# 2        9 2015-01-01 00:00:02         0
# 3        6 2015-01-01 00:00:03         0
# 4        6 2015-01-01 00:00:04         0

# %%
first_json.to_json('json_columns.json', orient="columns")

# %%
first_json.to_json('json_index.json', orient="index")

# %% [markdown]
# read_json() and to_json() works only with simple JSON. All arrays inside need to have arrays of same length.
#
# DOESN't SUPPORT NESTED JSON

# %%
file_path = '~/Documents/Lighthouse-lab/lighthouse-data-notes/Week_2/w2-d3/data/nested.json'
file = 'nested.json'
rel = './data'
df = pd.read_json(rel + file)
df = pd.read_json(file_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3d2e98036eee> in <module>
#       1 file_path = '~/Documents/Lighthouse-lab/lighthouse-data-notes/Week_2/w2-d3/data/nested.json'
#       2 #df = pd.read_json(rel + file)
# ----> 3 df = pd.read_json(file_path)
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# ...

# %%
with open('nested.json') as f:
    nested_json = json.load(f)
print(nested_json)
print(type(nested_json))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-ffb7d66863c5> in <module>
# ----> 1 with open('nested.json') as f:
#       2     nested_json = json.load(f)
#       3 print(nested_json)
#       4 print(type(nested_json))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nested.json'

# %%
#help(pd.read_json)
# Out:
# Help on function read_json in module pandas.io.json._json:
#
# read_json(path_or_buf=None, orient=None, typ='frame', dtype=None, convert_axes=None, convert_dates=True, keep_default_dates: bool = True, numpy: bool = False, precise_float: bool = False, date_unit=None, encoding=None, lines: bool = False, chunksize: Union[int, NoneType] = None, compression='infer', nrows: Union[int, NoneType] = None)
#     Convert a JSON string to pandas object.
#
#     Parameters
#     ----------
#     path_or_buf : a valid JSON str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, and file. For file URLs, a host is
#         expected. A local file could be:
#         ``file://localhost/path/to/table.json``.
#
#         If you want to pass in a path object, pandas accepts any
#         ``os.PathLike``.
#
#         By file-like object, we refer to objects with a ``read()`` method,
# ...
