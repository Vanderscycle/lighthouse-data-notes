# %%
from IPython.display import Image
import json
import pandas as pd

# %% [markdown]
# ### Get lecture resources from:

# %%
Image(filename='1.PNG')

# %%
Image(filename='2.PNG')

# %%
Image(filename='3.PNG')

# %%
Image(filename='4.PNG')

# %% [markdown]
# One value per data

# %% [markdown]
# ## Is the example tidy? (1)
# *Example source: https://garrettgman.github.io/tidying/*
#
# **Question: What variables are associated with the number of TB cases?**
#
# This data is tidy, true or false?
#
# | country | year  | cases_per_capita |
# |---------|-------|---|
# | Afghanistan | 1999|      745/19987071
# |Afghanistan |2000    | 2666/20595360
# |      Brazil |1999|   37737/172006362
# |      Brazil |2000  | 80488/174504898
# |      China |1999| 212258/1272915272
# |      China |2000 |213766/1280428583

# %%
Image(filename='t1.PNG')

# %% [markdown]
# ## Is the example tidy? (2)
#
# **Question: What variables are associated with the number of TB cases?**
#
# This data is tidy, true or false?
#
#
# | country | cases (year=1999) | cases (year=2000)| population (year=1999) | population (year=2000)|
# |---------|-------|-------|-------|-------|
# | Afghanistan |   745 |  2666 |  19987071 |  20595360 |
# |  Brazil | 37737 | 80488 | 172006362 | 174504898 |
# |  China | 212258 | 213766 | 1272915272 | 1280428583 |

# %%
Image(filename='t2.PNG')

# %% [markdown]
# ## Is the example tidy? (3)
#
# **Question: What variables are associated with the number of TB cases?**
#
# This data is tidy, true or false?
#
# | country | year  | cases | population |
# |---------|-------|-------|------------|
# | Afghanistan | 1999  |  745  | 19987071|
# | Afghanistan | 2000 |  2666 |  20595360|
# |Brazil |1999 | 37737  |172006362|
# | Brazil| 2000 | 80488 | 174504898|
# | China | 1999 | 212258 |1272915272|
# |  China |2000 | 213766 | 1280428583|

# %%
Image(filename='t3.PNG')

# %% [markdown]
# ## Is the example tidy? (4)
#
# **Question: What variables are associated with the number of TB cases?**
#
# This data is tidy, true or false?
#
# | country | year  | key | value |
# |---------|-------|-------|------------|
# |Afghanistan |1999 |     cases   |     745
# | Afghanistan |1999| population  | 19987071
# |  Afghanistan |2000|      cases |      2666
# |  Afghanistan| 2000| population |  20595360
# |       Brazil| 1999|      cases |     37737
# |       Brazil |1999| population | 172006362
# |       Brazil| 2000|      cases  |    80488
# |       Brazil |2000| population | 174504898
# |        China |1999|      cases  |   212258
# |       China |1999| population |1272915272
# |       China |2000|      cases |    213766
# |       China |2000| population| 1280428583

# %%
Image(filename='t4.PNG')

# %% [markdown]
# ## What other types of data is useful to data scientists?
#
# Exercise: Let's fill out this table together.
#
# | Data Type | Example | What are we trying to use it for? |
# |:-|:---------------------|:--------------------------------------------|
# | Text         | Tweets, scripts, books | Sentiment analysis, other NLP |
# | JSON or XML  | Parsing APIs | Gather data, data ingestion process, trend analysis, forecasting |
# | HTML         |Web scraping| Get prices of different products, Facebook / LinkedIn contacts and work history|
# | Excel        |BoM's       | Financial data, etc. |
# | Images       |Computer vision|Self-driving cars, building custom shoes, X-rays - diagnostics|
# | Time Series  |Speech analysis|Speech-to-text, medical signal analysis, sensor input analysis|
#
# - Text: will be covered in more detail when we're doing Natural Language Processing (NLP)
# - **JSON: we already covered, we'll talk a bit more about it today**
# - **XML and HTML: We'll talk through today**
# - **Excel: We'll cover today**
# - Images: will be covered in more detail when we're doing Convolutional Neural Networks (CNNs)
# - Time Series: will be covered later after we cover NLP

# %% [markdown]
# ## Data science intro to XML and HTML
# - hierarchical collection of elements
# - element consists of **start tag**, **content** and **end tag**, and **attributes**
# - tags have names and are delimited with `<` and `>`; end tag with `</ >`
# - attributes added after the tag name within `<` and `>`
#
# For example: `<country name="Canada">` content content `</country>`
# - `country` is the tag
# - `name="Canada"` is an attribute
#
# **HTML is just XML for webpages.**

# %% [markdown]
# ## Let's see a HTML example
#
# Let's take a look at an example: https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winners
# - Use inspect page to see HTML
# - Explain header, body, tags etc.

# %% [markdown]
# ## Let's see an Excel example

# %%
Image(filename='excel.PNG')

# %% [markdown]
# ## JSON - https://www.json.org/json-en.html
#
# - Basically a way to store, serve, transport information in the form/syntax of Java Script Objects == Python Dictionaries
# - JSON exists as a string — useful when you want to transmit data across a network.
# - JSON is purely a data format — it contains only properties, no methods.
# - JSON requires double quotes to be used around strings and property names. Single quotes are not valid.

# %% [markdown]
# # Break
#
# 10 mins

# %% [markdown]
# ## Different data, different tools
#
# 1. Tabular data: `pandas`, `SQL`
# * JSON: `json`
# * XML and HTML: `xml`
# * Can also use `BeautifulSoup` for HTML (will not cover, just so you know it exists)
#
# We will demo these.

# %% [markdown]
# ## Tabular data using pandas

# %%
import pandas as pd

# %%
wine_csv = pd.read_csv('data/wine.csv')
wine_csv
# Out:
#    Bottle         Grape     Origin  Alcohol    pH Colour   Aroma
# 0       1    Chardonnay  Australia    14.23  3.51  White  Floral
# 1       2  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2       3   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3       4        Shiraz      Chile    14.91  3.39    Red   Berry
# 4       5        Malbec  Argentina    13.83  3.28    Red  Fruity

# %%
wine_xlsx = pd.read_excel('data/wine.xlsx')
wine_xlsx
# Out:
#    Bottle         Grape     Origin  Alcohol    pH Colour   Aroma
# 0       1    Chardonnay  Australia    14.23  3.51  White  Floral
# 1       2  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2       3   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3       4        Shiraz      Chile    14.91  3.39    Red   Berry
# 4       5        Malbec  Argentina    13.83  3.28    Red  Fruity

# %% [markdown]
# ## Python and Excel
# - They are complementary! It's not a competition
# - Uses for both
# - For example:

# %%
wine_2 = pd.read_excel('data/wine_2.xlsx')
wine_2
# Out:
#   This workbook contains data for different wines
# 0                           Created by John Smith

# %% [markdown]
# - What's wrong?

# %% [markdown]
# ## Python and Excel ... continued
# - If I opened the Excel, I would find out that the useful data is on Sheet 2

# %%
wine_2 = pd.read_excel('data/wine_2.xlsx', sheet_name=1) # here, I reference the sheet name
wine_2
# Out:
#    Bottle         Grape     Origin  Alcohol    pH Colour   Aroma
# 0       1    Chardonnay  Australia    14.23  3.51  White  Floral
# 1       2  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2       3   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3       4        Shiraz      Chile    14.91  3.39    Red   Berry
# 4       5        Malbec  Argentina    13.83  3.28    Red  Fruity

# %% [markdown]
# ## JSON
#
# Here's some sample JSON: https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json

# %%
# You can read from the URL too!!
url = 'https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json'
json_data = pd.read_json(url)
json_data.head()
# Out:
#    integer            datetime  category
# 0        5 2015-01-01 00:00:00         0
# 1        5 2015-01-01 00:00:01         0
# 2        9 2015-01-01 00:00:02         0
# 3        6 2015-01-01 00:00:03         0
# 4        6 2015-01-01 00:00:04         0

# %%
#Another Example

json_data = pd.read_json('data/users.json')
json_data
# Out:
#                   sammy          jesse            drew              jamie
# username     SammyShark   JesseOctopus       DrewSquid  JamieMantisShrimp
# location   Indian Ocean  Pacific Ocean  Atlantic Ocean      Pacific Ocean
# online             True          False           False               True
# followers           987            432             321                654

# %% [markdown]
# ## JSON ... continued
# - `pd.read_json` doesn't work so well with nested JSON...
# - Let's take a look at what a nested JSON is...

# %%
# an error is supposed to happen when you run this cell

nested_json = pd.read_json('data/nested.json')
nested_json
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a55593cfa8d4> in <module>
#       1 # an error is supposed to happen when you run this cell
#       2
# ----> 3 nested_json = pd.read_json('data/nested.json')
#       4 nested_json
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~/miniconda3/envs/lighthouse-lab-course/lib/python3.8/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1117         if orient == "columns":
#    1118             self.obj = DataFrame(
# -> 1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#    1121         elif orient == "split":
#
# ValueError: Expected object or value

# %% [markdown]
# ## JSON ... continued
#
# - Instead, you can try this:

# %%
import json

with open('data/nested.json') as file:
    nested_json = json.load(file)

nested_json
# Out:
# {'article': [{'id': '01',
#    'language': 'JSON',
#    'edition': 'first',
#    'author': 'Allen'},
#   {'id': '02',
#    'language': 'Python',
#    'edition': 'second',
#    'author': 'Aditya Sharma'}],
#  'blog': [{'name': 'Datacamp', 'URL': 'datacamp.com'}]}

# %% [markdown]
# - What is the type?

# %%
type(nested_json)
# Out:
# dict

# %% [markdown]
# ## XML
# - Let's take a look at an XML file: https://drive.google.com/file/d/1Nfq42ss8jIqajaAOVdwzW4D3D5oL7Y2t/view
# - We use the `xml` package to work with XML

# %%
import xml.etree.ElementTree as et

# %%
# parses the XML so that it figures out the "tree" of tags
tree = et.parse('data/data.xml')
tree

# %%
# get to the root tag of the file
root = tree.getroot()
root
# Out:
# <Element 'data' at 0x7f336125d5e0>

# %% [markdown]
# ## XML ... continued
#
# From the root, we can begin to navigate the tree

# %%
# get root tag
print("What is the root tag:", root.tag)

# get root attributes
print("Attributes of the root tag:", root.attrib)

# get number of "children"
print("Number of children:", len(root))
# Out:
# What is the root tag: data
# Attributes of the root tag: {}
# Number of children: 3

# %%
# printing out the children of root
for idx in range(len(root)):
    print("tag:", root[idx].tag, "| attribute:", root[idx].attrib)
# Out:
# tag: country | attribute: {'name': 'Liechtenstein'}
# tag: country | attribute: {'name': 'Singapore'}
# tag: country | attribute: {'name': 'Panama'}

# %% [markdown]
# ## XML ... continued
#
# Let's continue exploring...

# %%
country1 = root[1]
rank = country1[3]
#rank = root[0][0] # works too
#for i in len(root):
    #rank = root[0][i]
print(country1.attrib)
print(rank.tag, ":", rank.attrib['name'])
# Out:
# {'name': 'Singapore'}
# neighbor : Malaysia

# %% [markdown]
# ### Get the neighbour of the 2nd country

# %%
country2 = root[1]
neighbour = country2[3]

print(country2.attrib['name'],'has neighbour',neighbour.attrib['name'])
# Out:
# Singapore has neighbour Malaysia

# %% [markdown]
# Can you follow where we got to on the `data.xml` file?

# %% [markdown]
# ## JSON tutorial

# %%
from pandas import json_normalize

# %%
nested_json
# Out:
# {'article': [{'id': '01',
#    'language': 'JSON',
#    'edition': 'first',
#    'author': 'Allen'},
#   {'id': '02',
#    'language': 'Python',
#    'edition': 'second',
#    'author': 'Aditya Sharma'}],
#  'blog': [{'name': 'Datacamp', 'URL': 'datacamp.com'}]}

# %%
json_normalize(nested_json)
# Out:
#                                              article  \
# 0  [{'id': '01', 'language': 'JSON', 'edition': '...
#
#                                             blog
# 0  [{'name': 'Datacamp', 'URL': 'datacamp.com'}]

# %%
blog = json_normalize(nested_json, record_path='blog')
blog.head()
# Out:
#        name           URL
# 0  Datacamp  datacamp.com

# %%
article = json_normalize(nested_json,record_path ='article')
article.head()
# Out:
#    id language edition         author
# 0  01     JSON   first          Allen
# 1  02   Python  second  Aditya Sharma

# %%
data = [{"state": "Florida", 
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [{"name": "Dade", "population": 12345},
                     {"name": "Broward", "population": 40000},
                     {"name": "Palm Beach", "population": 60000}]},
       {"state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [{"name": "Summit", "population": 1234},
                     {"name": "Cuyahoga", "population": 1337}]}]

# %%
json_normalize(data)
json_normalize(data=data, record_path='counties', meta=['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %%
json_normalize(data=data, meta=['state', 'shortname'])
# Out:
#      state shortname                                           counties  \
# 0  Florida        FL  [{'name': 'Dade', 'population': 12345}, {'name...
# 1     Ohio        OH  [{'name': 'Summit', 'population': 1234}, {'nam...
#
#   info.governor
# 0    Rick Scott
# 1   John Kasich

# %% [markdown]
# ## Scraping HTML from our previous Wiki

# %%
import bs4 as bs    #Beautiful soup
import urllib.request

# %%
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winning_players').read()

# %%
soup = bs.BeautifulSoup(source,'html')
#soup

# %%
# title of the page
print(soup.title)

# get attributes:
print(soup.title.name)

# get values:
print(soup.title.string)

# beginning navigation:
print(soup.title.parent.name)

# getting specific values:
print(soup.p)
# Out:
# <title>List of FIFA World Cup winning players - Wikipedia</title>
# title
# List of FIFA World Cup winning players - Wikipedia
# head
# <p>This is a list of all players who have won the <a href="/wiki/FIFA_World_Cup" title="FIFA World Cup">FIFA World Cup</a> tournament since its inception in 1930.
# </p>
