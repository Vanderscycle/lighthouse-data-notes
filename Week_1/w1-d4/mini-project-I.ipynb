# %% [markdown]
# # Mini-Project I
# During this project, we will practice handling of complex lists and dictionaries in Python. Plus, we will learn how to work with API documentation. Don't be afraid to search for the information in the [**documentation**](https://api.tfl.gov.uk/swagger/ui/index.html?url=/swagger/docs/v1#!/AccidentStats/AccidentStats_Get).
#
# Let's go to the tasks, we have some parsing to do :)!!

# %%
# import packages we need (remember what packages we used yesterday during the API session)
import requests
import json
from IPython.display import JSON

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %% [markdown]
# ## Demo

# %%
# London API is udner construction
#app_id = '<your App ID>'
#app_key = '<your App Key>'
#url_append = f'?app_id={app_id}&app_key={app_key}'

# %%
#print(url_append)

# %%
# URL
url = "https://api.tfl.gov.uk/AirQuality"

# %%
# We send the request to the API
# NOTE: if you don't have your APP_KEY, run this without the url_append
res = requests.get(url)#+url_append)

# %%
# We can check if the request was successful
res.status_code
# Out:
# 200

# %%
# We can export the information that was returned using method .json()
#res.json()

# %% [markdown]
# ## Task
# Parse the dictionary and print the AirQuality predictions for tomorrow
# YOU DIDN'T ANSWER THE QUESTION

# %%
#res.headers

# %%
res.encoding = 'utf-8'
json_res = res.json()
JSON_res = JSON(res.json())
print(type(json_res))
#print(json_res['currentForecast'])

print('\n', json_res['currentForecast'][1]['forecastText'])


#dir(requests)
# Out:
# <class 'dict'>
#
#  A continuing feed of air from continental Europe into Greater London is forecast by back-trajectory models for Saturday. As on Friday though, a marked import of long-range particulates is not currently expected as the predicted speed and altitude of the incoming air will limit the potential for it to accumulate pollutants.&lt;br/&gt;Again, a good easterly breeze should give good dispersion of local emissions.&lt;br/&gt;Similar forecast is for Sunday. &lt;br/&gt;Dry and sunny on Monday with lighter winds from the east. Pollution levels for Monday will be reviewed over the weekend  &lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; throughout the forecast period for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM2.5 Particulates&lt;br/&gt;PM10 Particulates&lt;br/&gt;&lt;br/&gt;

# %%
JSON_res

# %% [markdown]
# ## Task
# What are the different modes of transport which are operated by Transfer for London? How many of modes do they have?
#
# Print the list with different modes of transport, plus their count. Example output:
# ```
# [bus, cable-car,.....]
# Number of different modes of transport is: xyz
# ```
#
# We need to search the documentation for correct request.

# %%
url = "https://api.tfl.gov.uk/"
current_var = 'Line/Meta/Modes'
res = requests.get(url + current_var)

# %%
json_res = res.json()
# how many modes of transport are operated by Transfer for London?
print(f'Number of different modes of transport: {len(json_res)}')
list_of_modes = list()
for x in range(len(json_res)):
    #print (json_res[x]['modeName'])
    list_of_modes.append(json_res[x]['modeName'])
    
print(f'The following modes are provided by Transport London: {list_of_modes}')
JSON_res = JSON(res.json())
# Out:
# Number of different modes of transport: 18
# The following modes are provided by Transport London: ['bus', 'cable-car', 'coach', 'cycle', 'cycle-hire', 'dlr', 'interchange-keep-sitting', 'interchange-secure', 'national-rail', 'overground', 'replacement-bus', 'river-bus', 'river-tour', 'taxi', 'tflrail', 'tram', 'tube', 'walking']

# %%
JSON_res

# %% [markdown]
# ## Task
# How many BikePoints in London are operated by Transfor for London? How many docks are in **all** BikePoints? There is the information for empty and full docks for each BikePoint.

# %% [markdown]
# ## Known issues
# You want to loop through the Json and look for specific keys instead of

# %%
current_var = 'BikePoint'
#t = 'nbBikes'
res = requests.get(url + current_var)

# %%
json_res = res.json()
JSON_res = JSON(res.json())
# How many BikePoints in London are operated by Transfor for London?
#print(f'{len(json_res)}')

# issue: loop through the JSON looking for the ""

print(json_res[1]['additionalProperties'][8]['value'])
print(type(json_res[1]['additionalProperties'][8]['value']))


val_str = json_res[1]['additionalProperties'][8]['value']
val_int = int(val_str)

print(val_int)
print(type(val_int))

total_docks = 0


for bike in range(len(json_res)):
    val_str = json_res[bike]['additionalProperties'][8]['value']
    val_int = int(float(val_str))
    total_docks += val_int
print(total_docks)
    

    

#  How many docks are in all BikePoints?
# Out:
# 32
# <class 'str'>
# 32
# <class 'int'>
# 20853

# %%
JSON_res

# %% [markdown]
# ## Task
# How many tube and bus lines are in London? Print names of all tube lines.

# %%
current_var = 'Line/Mode/tube'
res_tube = requests.get(url + current_var)
json_res_tube = res_tube.json()
JSON_res_tube = JSON(res_tube.json())
print(f'status code tubes {res_tube.status_code}')

current_var = 'Line/Mode/bus'
res_bus = requests.get(url + current_var)
json_res_bus = res_bus.json()
JSON_res_bus = JSON(res_bus.json())
print(f'status code bus {res_bus.status_code}')

print(f'The number of bus in London: {len(json_res_bus)}')
print(f'The number of tubes in London: {len(json_res_tube)}')
# Out:
# status code tubes 200
# status code bus 200
# The number of bus in London: 681
# The number of tubes in London: 11

# %%
#JSON_res_bus
JSON_res_tube

# %% [markdown]
# ## Task
# How many station has `victoria` line?

# %%
current_var = 'Line/victoria/StopPoints'
res_tube_vic = requests.get(url + current_var)
json_res_tube_vic_s = res_tube_vic.json()
JSON_res_tube_vic_s = JSON(json_res_tube_vic_s)
print(f'status code bus {res_tube_vic.status_code}')
print(f'The number of station for the Victoria line is: {len(json_res_tube_vic_s)}')
# Out:
# status code bus 200
# The number of station for the Victoria line is: 16

# %%
#JSON_res_tube_vic_s

# %% [markdown]
# FIINDING THE NAPCAN CODES

# %%
current_var = 'Line/piccadilly/StopPoints'
res_tube_vic = requests.get(url + current_var)
json_res_tube_vic_s = res_tube_vic.json()
JSON_res_tube_vic_s = JSON(json_res_tube_vic_s)
print(f'status code bus {res_tube_vic.status_code}')
print(f'The number of station for the Victoria line is: {len(json_res_tube_vic_s)}')
# Out:
# status code bus 200
# The number of station for the Victoria line is: 52

# %%
for stop in range(len(json_res_tube_vic_s)):
    #print(json_res_tube_vic_s[stop]['commonName'])
    if 'Heathrow' in json_res_tube_vic_s[stop]['commonName']:
        print(json_res_tube_vic_s[stop]['commonName'])
        print (json_res_tube_vic_s[stop]['stationNaptan'])
# Out:
# Heathrow Terminal 5 Underground Station
# 940GZZLUHR5
# Heathrow Terminals 2 & 3 Underground Station
# 940GZZLUHRC

# %%
JSON_res_tube_vic_s

# %% [markdown]
# ## Task
# Plan the journey from Heathrow Airport to Tower Bridge using Public Transport, Taxi or Bike? Which way is the fastest? Example output:
# ```
# Planned duration:
# Public Transport: x minutes
# Bike: y minutes
# ```
#
# We need to search the documentation for correct requests.

# %% [markdown]
# ## Known issues:
# We are not looping through,but instead to manually searching them. BAD!!!

# %%
#tube 
tube = 'mode=tube'
current_var = 'Journey/JourneyResults/TW6%201AP/to/SE1%204TW?mode=tube'

current_var = 'Journey/JourneyResults/TW6%201AP/to/SE1%204TW?mode=cycle'

res_j = requests.get(url + current_var)
json_res_j  = res_j.json()
JSON_res_j  = JSON(res_j.json())
print(f'status code bus {res_j.status_code}')
#JSON_res_j  = JSON(res_j)
# Out:
# status code bus 404

# %%
#JSON_res_j

# %% [markdown]
# ## Journey time by tube

# %%
dep = 'Hillingdon, London Heathrow Airport terminal 5'
dest = 'City of London, Tower Bridge'
mode = 'tube'

current_var = f'Journey/JourneyResults/{dep}/to/{dest}?Mode={mode}'
res_t = requests.get(url + current_var)
print(f'status code bus {res_t.status_code}')
res_t_json = res_t.json()
JSON_res_t = JSON(res_t_json)
# Out:
# status code bus 200

# %%
shortest_route = 9e10
for leg in range(len(res_t_json['journeys'])):
    current_tube_time = int(res_t_json['journeys'][leg]['duration'])
    if current_tube_time < shortest_route:
        shortest_route = current_tube_time
print(f'The total travel time by tube is: {shortest_route}')
# Out:
# The total travel time by tube is: 87

# %% [markdown]
# ## Journey time by bike

# %%
mode = 'cycle'

current_var = f'Journey/JourneyResults/{dep}/to/{dest}?Mode={mode}'
res_c = requests.get(url + current_var)
print(f'status code bus {res_c.status_code}')
res_c_json = res_c.json()
# Out:
# status code bus 200

# %%
shortest_route = 9e10
for leg in range(len(res_c_json['journeys'])):
    current_bike_time = int(res_c_json['journeys'][leg]['duration'])
    if current_tube_time < shortest_route:
        shortest_route = current_tube_time
    #total_time_cycle += int(res_c_json['journeys'][leg]['duration'])
print(f'The total travel time by cycling is: {shortest_route}')
#tube_travel_time_s
# Out:
# The total travel time by cycling is: 89

# %% [markdown]
# ## Journey time by bus

# %%
mode = 'bus'

current_var = f'Journey/JourneyResults/{dep}/to/{dest}?Mode={mode}'
res_b = requests.get(url + current_var)
print(f'status code bus {res_b.status_code}')
res_b_json = res_b.json()
# Out:
# status code bus 200

# %%
better_v = JSON(res_b_json)
better_v

# %%
shortest_route = 9e10

for leg in range(len(res_b_json['journeys'])):
    current_bus_time = int(res_b_json['journeys'][leg]['duration'])
    if current_bus_time < shortest_route:
        shortest_route = current_bus_time
        
   # total_time_bus += int(res_b_json['journeys'][leg]['duration'])
print(f'The total travel time by bus is: {shortest_route}')
#tube_travel_time_s
# Out:
# The total travel time by bus is: 133

# %% [markdown]
# ## Journey time by taxi
#
# # doesn't work uses bus/tube and else

# %%
#mode = 'cycle'

mode='black-cab-as-customer'
current_var = f'Journey/JourneyResults/{dep}/to/{dest}?Mode={mode}'
res_ta = requests.get(url + current_var)
print(f'status code bus {res_ta.status_code}')
res_ta_json = res_ta.json()
# Out:
# status code bus 200

# %%
shortest_route = 9e10
for leg in range(len(res_ta_json['journeys'])):
    current_taxi_time = int(res_ta_json['journeys'][leg]['duration'])
    if current_taxi_time < shortest_route:
        shortest_route = current_taxi_time
print(f'The total travel time by taxi is: {total_time_taxi}')
#tube_travel_time_s
# Out:
# The total travel time by taxi is: 257

# %%
better_v = JSON(res_ta_json)
better_v
