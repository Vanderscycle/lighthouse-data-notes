# %%
# import numpy
import numpy as np

# import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line plot

# %%
plt.style.use('dark_background')
# 200 values from the interval <0,100>, equidistantly divided
x = np.linspace(0,100,200)
y = np.sin(x)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# plot the line
ax.plot(x,y,'red')
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
# 200 random values from the interval <0,10>
x = 10*np.random.rand(200,1)

# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# scatter plot
ax.scatter(x,y)
plt.show()

# %% [markdown]
# ## Histogram

# %%
# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# histogram
ax.hist(y,bins=20)
plt.show()

# %%
## Graph on common axes

# %%
# 200 values from the interval <0,100>, equidistantly divided
x = np.linspace(0,100,200)

# sin(x) values
y1 = np.sin(x)

# sin(x)*cos(x) values
y2 =(np.sin(x))*(np.cos(x))

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# sin(x) plot 
ax.plot(x,y1,'red')

# sin(x)*cos(x) plpt
ax.plot(x,y2,'blue')
plt.show()

# %% [markdown]
# ## Subplot

# %%
# create the figure and axes, set the figure size
fig, axes = plt.subplots(nrows=2, ncols=1 ,figsize = (10,6))

# the first plot 
axes[0].plot(x,y1,'red')

# the first plot title
axes[0].set_title('sin(x)')

# the second plot
axes[1].plot(x,y2,'blue')

# the second plot title
axes[1].set_title('sin(x)*(cos(x))')

# automatically adjust the subplot parameters to give specified padding
fig.tight_layout()
plt.show()

# %%
# create the figure and axes, set the figure size
fig, axes = plt.subplots(nrows=2, ncols=2 ,figsize = (10,6))

# the first plot 
axes[0][0].plot(x,y1,'red')

# the first plot title
axes[0][0].set_title('sin(x)')

# the second plot
axes[1][0].plot(x,y2,'blue')

# the second plot title
axes[1][0].set_title('sin(x)*(cos(x))')

# automatically adjust the subplot parameters to give specified padding
fig.tight_layout()
plt.show()

# %%
# import pandas
import pandas as pd

# import sklearn datasets
from sklearn import datasets

# %%
# load the iris dataset
iris = datasets.load_iris()

# create a dataframe
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# create a target
iris_df['target'] = iris.target

# map target values to target names
iris_df['target_name'] =iris_df.target.map(
    {0: 'setosa', 
     1: 'versicolor',
     2: 'virginica'}
)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
type(iris)
# Out:
# sklearn.utils.Bunch

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
# Iris setosa
setosa = iris_df[iris_df.target_name == 'setosa']

# Iris versicolor
versicolor = iris_df[iris_df.target_name == 'versicolor']

# Iris virginica
virginica = iris_df[iris_df.target_name == 'virginica']

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize=(10,6))

# scatter the plot of setosa
ax.scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')


# scatter the plot of versicolor
ax.scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')


# scatter the plot of virginica
ax.scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# set the legend
ax.legend(loc='upper right')

# set the title
ax.set_title('Iris flower')

# set the x-label
ax.set_xlabel('sepal length (cm)')

# set the y-label
ax.set_ylabel('sepal width (cm)')
plt.show()

# %%
# Iris setosa
setosa = iris_df[iris_df.target_name == 'setosa']

# Iris versicolor
versicolor = iris_df[iris_df.target_name == 'versicolor']

# Iris virginica
virginica = iris_df[iris_df.target_name == 'virginica']

# create the figure and axes, set the figure size

fig, ax = plt.subplots(nrows=2, ncols=2 ,figsize = (10,6))
# scatter the plot of setosa
ax[0][0].scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')


# scatter the plot of versicolor
ax[1][0].scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')


# scatter the plot of virginica
ax[1][1].scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# set the legend
#ax.legend(loc='upper right')

# set the title
#fig.suptitle('Categorical Plotting')
fig.suptitle('Iris flower')
#ax.set_title('Iris flower')

# set the x-label
#ax.set_xlabel('sepal length (cm)')
# Set common labels


# set the y-label
#ax.set_ylabel('sepal width (cm)')
plt.show()

# %%
# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize=(10,6))

# scatter the plot of setosa
ax.scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')


# scatter the plot of versicolor
ax.scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')


# scatter the plot of virginica
ax.scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# new lines of code
######################
ax.annotate('setosa', xy =(5.0,3.5),
             xytext = (4.25,4.0), arrowprops={'color':'red'})
ax.annotate('versicolor', xy =(7.2,3.6),
             xytext = (6.5,4.0), arrowprops={'color':'red'})
ax.annotate('virginica', xy =(5.05,1.95),
             xytext = (5.5,1.75), arrowprops={'color':'red'})
######################


# set the legend
ax.legend(loc='upper right')

# set the title
ax.set_title('Iris flower')

# set the x-label
ax.set_xlabel('sepal length (cm)')

# set the y-label
ax.set_ylabel('sepal width (cm)')

# set the x-range 
ax.set_xlim(4,8)

# set the y-range
ax.set_ylim(1.5,4.7)
plt.show()
